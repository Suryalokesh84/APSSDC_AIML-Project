# %%
#Problem statement
#Develop a sentiment analysis model to classify restarunt reviews as positve or negative

# %%
#Description
# with the rapid growth of online platforms for sharing opinions and reviews,restarunts often rely 
#on the customer feedback to imporve their services and attract   a new customers.
# Analyzing the sentiment of these reviews can provide valuable insights into customer satisfaction.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: C:\Users\Sandya\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
data = pd.read_csv('Reviews.csv')

# %%
data
# Out:
#                                                 Review  Liked
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
# [1000 rows x 2 columns]

# %%
data.head() # Top 5 rows of the data set
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
data.tail() # Last 5 rows of the data set
# Out:
#                                                 Review  Liked
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0

# %%
data.info() # information of the dat set like , data type , memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  1000 non-null   object
#  1   Liked   1000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 15.8+ KB

# %%
data.describe() # stastical information of the data set
# Out:
#             Liked
# count  1000.00000
# mean      0.50000
# std       0.50025
# min       0.00000
# 25%       0.00000
# 50%       0.50000
# 75%       1.00000
# max       1.00000

# %%
#checking the null values of the data set
data.isnull().sum()
# Out:
# Review    0
# Liked     0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
#checking the value counts
value_counts = data['Liked'].value_counts()
print(value_counts)
# Out:
# Liked
# 1    500
# 0    500
# Name: count, dtype: int64

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: C:\Users\Sandya\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: C:\Users\Sandya\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
value_counts.plot(kind = 'bar' , color = ['blue', 'green'])
plt.title("Sentiment value counts")
plt.xlabel('Liked')
plt.ylabel('Count')
plt.xticks(ticks=[0,1] , labels=['Postive','Negative'],rotation=0)
plt.show()

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from wordcloud) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->wordcloud) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->wordcloud) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: C:\Users\Sandya\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from wordcloud import WordCloud

# %%
combined_text = " ".join(data['Review'])
wordcloud = WordCloud(width = 800 , height = 400 ,background_color = 'white').generate(combined_text)
plt.figure(figsize=(10,6))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title('Word Cloud of Reviews')
plt.show()

# %%
from collections import Counter

# %%
target_words = ['food','place','restaurant']
all_words = " ".join(data['Review']).lower().split()
word_counts = Counter(all_words)
target_word_counts = {word:word_counts[word] for word in target_words}
plt.figure(figsize=(8,6))
plt.bar(target_word_counts.keys(),target_word_counts.values() , color = ['blue','green','orange'])
plt.xlabel('words')
plt.ylabel('Frequenecy')
plt.title('Frequency of specific words in Reviews')
plt.show()

# %%
#Text preprocessing

# %%
#convert a data set into lower case
lowercased_text = data['Review'].str.lower()

# %%
print(lowercased_text)
# Out:
# 0                               wow... loved this place.
# 1                                     crust is not good.
# 2              not tasty and the texture was just nasty.
# 3      stopped by during the late may bank holiday of...
# 4      the selection on the menu was great and so wer...
#                              ...
# 995    i think food should have flavor and texture an...
# 996                             appetite instantly gone.
# 997    overall i was not impressed and would not go b...
# 998    the whole experience was underwhelming, and i ...
# 999    then, as if i hadn't wasted enough of my life ...
# Name: Review, Length: 1000, dtype: object

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: colorama in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: C:\Users\Sandya\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
#tokinization
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Sandya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data['Tokens'] = data['Review'].apply(word_tokenize)

# %%
print(data['Tokens'])
# Out:
# 0                      [Wow, ..., Loved, this, place, .]
# 1                              [Crust, is, not, good, .]
# 2      [Not, tasty, and, the, texture, was, just, nas...
# 3      [Stopped, by, during, the, late, May, bank, ho...
# 4      [The, selection, on, the, menu, was, great, an...
#                              ...
# 995    [I, think, food, should, have, flavor, and, te...
# 996                       [Appetite, instantly, gone, .]
# 997    [Overall, I, was, not, impressed, and, would, ...
# 998    [The, whole, experience, was, underwhelming, ,...
# 999    [Then, ,, as, if, I, had, n't, wasted, enough,...
# Name: Tokens, Length: 1000, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  1000 non-null   object
#  1   Liked   1000 non-null   int64
#  2   Tokens  1000 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 23.6+ KB

# %%
data['Review'].value_counts()
# Out:
# Review
# #NAME?                                                                                                                                    4
# The food was terrible.                                                                                                                    2
# I would not recommend this place.                                                                                                         2
# I love this place.                                                                                                                        2
# I won't be back.                                                                                                                          2
#                                                                                                                                          ..
# OMG, the food was delicioso!                                                                                                              1
# There is nothing authentic about this place.                                                                                              1
# the spaghetti is nothing special whatsoever.                                                                                              1
# Of all the dishes, the salmon was the best, but all were great.                                                                           1
# Then, as if I hadn't wasted enough of my life there, they poured salt in the wound by drawing out the time it took to bring the check.    1
# Name: count, Length: 993, dtype: int64

# %%
import string

# %%
data['Review'] = data['Review'].str.replace(f"[{string.punctuation}]"," ",regex = True)

# %%
print(data['Review'])
# Out:
# 0                               Wow    Loved this place
# 1                                     Crust is not good
# 2              Not tasty and the texture was just nasty
# 3      Stopped by during the late May bank holiday of...
# 4      The selection on the menu was great and so wer...
#                              ...
# 995    I think food should have flavor and texture an...
# 996                             Appetite instantly gone
# 997    Overall I was not impressed and would not go b...
# 998    The whole experience was underwhelming  and I ...
# 999    Then  as if I hadn t wasted enough of my life ...
# Name: Review, Length: 1000, dtype: object

# %%
data['Review'].value_counts()
# Out:
# Review
#  NAME                                                                                                                                     4
# I would not recommend this place                                                                                                          2
# I love this place                                                                                                                         2
# I won t be back                                                                                                                           2
# Will not be back                                                                                                                          2
#                                                                                                                                          ..
# The burger    I got the  Gold Standard  a  17 burger and was kind of disappointed                                                         1
# OMG  the food was delicioso                                                                                                               1
# There is nothing authentic about this place                                                                                               1
# the spaghetti is nothing special whatsoever                                                                                               1
# Then  as if I hadn t wasted enough of my life there  they poured salt in the wound by drawing out the time it took to bring the check     1
# Name: count, Length: 992, dtype: int64

# %%
#Removing the stop words like this, is , are ,was 
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Sandya\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
data['Tokens'] = data['Review'].apply(lambda x: [word for word in word_tokenize(x) if word not in stop_words])

# %%
print(data['Tokens'])
# Out:
# 0                                    [Wow, Loved, place]
# 1                                          [Crust, good]
# 2                           [Not, tasty, texture, nasty]
# 3      [Stopped, late, May, bank, holiday, Rick, Stev...
# 4                  [The, selection, menu, great, prices]
#                              ...
# 995           [I, think, food, flavor, texture, lacking]
# 996                          [Appetite, instantly, gone]
# 997             [Overall, I, impressed, would, go, back]
# 998    [The, whole, experience, underwhelming, I, thi...
# 999    [Then, I, wasted, enough, life, poured, salt, ...
# Name: Tokens, Length: 1000, dtype: object

# %%
#stemming
#stemming is the process of reducing the a word into root or base word form by removig suffix 
#example : driving stemmed is drive

# %%
#Stemming
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
stemmer = PorterStemmer()

# %%
data['stemmed'] = data['Review'].apply(lambda x: ' '.join([stemmer.stem(word) for word in word_tokenize(x)]))

# %%
print(data['stemmed'])
# Out:
# 0                                     wow love thi place
# 1                                      crust is not good
# 2                 not tasti and the textur wa just nasti
# 3      stop by dure the late may bank holiday off ric...
# 4      the select on the menu wa great and so were th...
#                              ...
# 995    i think food should have flavor and textur and...
# 996                               appetit instantli gone
# 997        overal i wa not impress and would not go back
# 998    the whole experi wa underwhelm and i think we ...
# 999    then as if i hadn t wast enough of my life the...
# Name: stemmed, Length: 1000, dtype: object

# %%
#Lemmatization
#Lemmatization is the process transforming a word into its base or dictionary form
#example is better is lemmtized to good

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Sandya\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet

# %%
lemmatizer = WordNetLemmatizer()

# %%
data['Lemmatized'] = data['Review'].apply(lambda x :' '.join([lemmatizer.lemmatize(word , pos = wordnet.VERB) for word in word_tokenize(x)]))

# %%
print(data['Lemmatized'])
# Out:
# 0                                   Wow Loved this place
# 1                                      Crust be not good
# 2                Not tasty and the texture be just nasty
# 3      Stopped by during the late May bank holiday of...
# 4      The selection on the menu be great and so be t...
#                              ...
# 995    I think food should have flavor and texture an...
# 996                                Appetite instantly go
# 997       Overall I be not impress and would not go back
# 998    The whole experience be underwhelming and I th...
# 999    Then as if I hadn t waste enough of my life th...
# Name: Lemmatized, Length: 1000, dtype: object

# %%
#Removing the numbers from reviews
import re
data['No_Numbers'] = data['Review'].apply(lambda x : re.sub(r'\d+',' ' ,x))

# %%
print(data['No_Numbers'])
# Out:
# 0                               Wow    Loved this place
# 1                                     Crust is not good
# 2              Not tasty and the texture was just nasty
# 3      Stopped by during the late May bank holiday of...
# 4      The selection on the menu was great and so wer...
#                              ...
# 995    I think food should have flavor and texture an...
# 996                             Appetite instantly gone
# 997    Overall I was not impressed and would not go b...
# 998    The whole experience was underwhelming  and I ...
# 999    Then  as if I hadn t wasted enough of my life ...
# Name: No_Numbers, Length: 1000, dtype: object

# %%
#removing special characters like @ # %,*
data['cleaned'] = data['Review'].apply(lambda x: re.sub(r'[^A-Za-z0-9\s]','' ,x))

# %%
print(data['cleaned'])
# Out:
# 0                               Wow    Loved this place
# 1                                     Crust is not good
# 2              Not tasty and the texture was just nasty
# 3      Stopped by during the late May bank holiday of...
# 4      The selection on the menu was great and so wer...
#                              ...
# 995    I think food should have flavor and texture an...
# 996                             Appetite instantly gone
# 997    Overall I was not impressed and would not go b...
# 998    The whole experience was underwhelming  and I ...
# 999    Then  as if I hadn t wasted enough of my life ...
# Name: cleaned, Length: 1000, dtype: object

# %%
#expanding method
# don't eat food in this hotel , when we apply expanted text it will convert into do not eat food in this hotel

# %%
pip install contractions
# Out:
# Requirement already satisfied: contractions in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from textsearch>=0.0.21->contractions) (0.3.2)
# Requirement already satisfied: pyahocorasick in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from textsearch>=0.0.21->contractions) (2.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: C:\Users\Sandya\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import contractions
data['Expanded'] = data['Review'].apply(contractions.fix)

# %%
print(data['Expanded'])
# Out:
# 0                               Wow    Loved this place
# 1                                     Crust is not good
# 2              Not tasty and the texture was just nasty
# 3      Stopped by during the late May bank holiday of...
# 4      The selection on the menu was great and so wer...
#                              ...
# 995    I think food should have flavor and texture an...
# 996                             Appetite instantly gone
# 997    Overall I was not impressed and would not go b...
# 998    The whole experience was underwhelming  and I ...
# 999    Then  as if I hadn t wasted enough of my life ...
# Name: Expanded, Length: 1000, dtype: object

# %%
#Removing emojis

# %%
import emoji
data['emoji'] = data['Review'].apply(emoji.demojize)

# %%
print(data['emoji'])
# Out:
# 0                               Wow    Loved this place
# 1                                     Crust is not good
# 2              Not tasty and the texture was just nasty
# 3      Stopped by during the late May bank holiday of...
# 4      The selection on the menu was great and so wer...
#                              ...
# 995    I think food should have flavor and texture an...
# 996                             Appetite instantly gone
# 997    Overall I was not impressed and would not go b...
# 998    The whole experience was underwhelming  and I ...
# 999    Then  as if I hadn t wasted enough of my life ...
# Name: emoji, Length: 1000, dtype: object

# %%
# removing liks from review_ text
# food is good vist www.abchotel.in

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.12.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: soupsieve>1.2 in c:\users\sandya\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from beautifulsoup4) (2.5)
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: C:\Users\Sandya\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from bs4 import BeautifulSoup

# %%
data['cleaned'] = data['Review'].apply(lambda x: BeautifulSoup(x,"html.parser").get_text())

# %%
print(data['cleaned'])
# Out:
# 0                               Wow    Loved this place
# 1                                     Crust is not good
# 2              Not tasty and the texture was just nasty
# 3      Stopped by during the late May bank holiday of...
# 4      The selection on the menu was great and so wer...
#                              ...
# 995    I think food should have flavor and texture an...
# 996                             Appetite instantly gone
# 997    Overall I was not impressed and would not go b...
# 998    The whole experience was underwhelming  and I ...
# 999    Then  as if I hadn t wasted enough of my life ...
# Name: cleaned, Length: 1000, dtype: object
